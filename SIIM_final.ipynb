# %% [markdown]
# <a href="https://colab.research.google.com/github/pspencer504/SIIM/blob/main/SIIM_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Code that queries SIIM base
#%pip install fhir.resources

import requests
import json

apikey = "095852d6-543c-4e06-98f0-11ffe7ffc105"
headers = {
      'Content-Type' : "application/json",
      'Accept': "application/json",
      'apikey': "095852d6-543c-4e06-98f0-11ffe7ffc105"
      }

#define JSON query URLs
medEffect_query_url = "https://hackathon.siim.org/fhir-r4/MedicinalProductUndesirableEffect?_id=149"
report_query_url = "https://hackathon.siim.org/fhir-r4/DiagnosticReport?result=Observation/154"
medication_query_url = "https://hackathon.siim.org/fhir-r4/Medication?_id=148"
medicationStatement_query_url = "https://hackathon.siim.org/fhir-r4/MedicationStatement?subject=Patient/siimirene"
patientInfo_query_url = "https://hackathon.siim.org/fhir-r4/Patient?family=SIIM&given=Irene"

siderosis_observation_query_url = "https://hackathon.siim.org/fhir-r4/Observation?code=G96.8"
hem_observation_query_url = "https://hackathon.siim.org/fhir-r4/Observation?code=I61.8"
dep_observation_query_url = "https://hackathon.siim.org/fhir-r4/Observation?code=F32.A"
neur_observation_query_url = "https://hackathon.siim.org/fhir-r4/Observation?code=G60.3"

siderosis_condition_query_url = "https://hackathon.siim.org/fhir-r4/Condition?code=G96.8"
hem_condition_query_url = "https://hackathon.siim.org/fhir-r4/Condition?code=I61.8"
dep_condition_query_url = "https://hackathon.siim.org/fhir-r4/Condition?code=F32.A"
neur_condition_query_url = "https://hackathon.siim.org/fhir-r4/Condition?code=G60.3"
alzheimers_condition_query_url = "https://hackathon.siim.org/fhir-r4/Condition?code=G30.9"



#fetch JSON files using URLs
medEffect_response = requests.request("GET", medEffect_query_url, headers=headers)
report_response = requests.request("GET", report_query_url, headers=headers)
medicationStateme_response = requests.request("GET", medication_query_url, headers=headers)
medication_response = requests.request("GET", medication_query_url, headers=headers)
patientInfo_response = requests.request("GET", patientInfo_query_url, headers=headers)

hem_observation_response = requests.request("GET", hem_observation_query_url, headers=headers)
siderosis_observation_response = requests.request("GET", siderosis_observation_query_url, headers=headers)
dep_observation_response = requests.request("GET", dep_observation_query_url, headers=headers)
neur_observation_response = requests.request("GET", neur_observation_query_url, headers=headers)

alzheimers_condition_response = requests.request("GET", alzheimers_condition_query_url, headers=headers)
hem_condition_response = requests.request("GET", hem_condition_query_url, headers=headers)
siderosis_condition_response = requests.request("GET", siderosis_condition_query_url, headers=headers)
dep_condition_response = requests.request("GET", dep_condition_query_url, headers=headers)
neur_condition_response = requests.request("GET", neur_condition_query_url, headers=headers)



#create JSON files from fetch responses
medEffect_json = json.loads(medEffect_response.text)
report_json = json.loads(report_response.text)
medication_json = json.loads(medication_response.text)
patientInfo_json = json.loads(patientInfo_response.text)

hem_observation_json = json.loads(hem_observation_response.text)
siderosis_observation_json = json.loads(siderosis_observation_response.text)
dep_observation_json = json.loads(dep_observation_response.text)
neur_observation_json = json.loads(neur_observation_response.text)

alzheimers_condition_json = json.loads(alzheimers_condition_response.text)
hem_condition_json = json.loads(hem_condition_response.text)
siderosis_condition_json = json.loads(siderosis_condition_response.text)
dep_condition_json = json.loads(dep_condition_response.text)
neur_condition_json = json.loads(neur_condition_response.text)


#expore JSON files to Colab directory to be able to view them
with open("medEffect.json", "w") as outfile:
    json.dump(medEffect_json, outfile, indent=2)
with open("report.json", "w") as outfile:
    json.dump(report_json, outfile, indent=2)
with open("medication.json", "w") as outfile:
    json.dump(medication_json, outfile, indent=2)
with open("patientInfo.json", "w") as outfile:
    json.dump(patientInfo_json, outfile, indent=2)

with open("hem_observation_json", "w") as outfile:
    json.dump(hem_observation_json, outfile, indent=2)
with open("siderosis_observation_json", "w") as outfile:
    json.dump(siderosis_observation_json, outfile, indent=2)
with open("dep_observation_json", "w") as outfile:
    json.dump(dep_observation_json, outfile, indent=2)
with open("neur_observation_json", "w") as outfile:
    json.dump(neur_observation_json, outfile, indent=2)

with open("alzheimers_condition.json", "w") as outfile:
    json.dump(alzheimers_condition_json, outfile, indent=2)
with open("hem_condition_json", "w") as outfile:
    json.dump(hem_condition_json, outfile, indent=2)
with open("siderosis_condition_json", "w") as outfile:
    json.dump(siderosis_condition_json, outfile, indent=2)
with open("dep_condition_json", "w") as outfile:
    json.dump(dep_condition_json, outfile, indent=2)
with open("neur_condition_json", "w") as outfile:
    json.dump(neur_condition_json, outfile, indent=2)


# Parsing through json objects
code_value_alz = alzheimers_condition_json["entry"][0]["resource"]["code"]["coding"][0]["code"]
# might want to use display name
code_value_med = medication_json["entry"][0]['resource']['code']['coding'][0]['code']
code_value_dep = dep_observation_json["entry"][0]['resource']['code']['coding'][0]['code']
code_value_hem = hem_observation_json["entry"][0]['resource']['code']['coding'][0]['code']
code_value_medEffect = medEffect_json["entry"][0]['resource']['symptomConditionEffect']['coding'][0]['code']
code_value_neur = neur_observation_json["entry"][0]['resource']['code']['coding'][0]['code']
# probably need to add an index to which refrence we want...
code_value_report = report_json["entry"][0]['resource']['result']

print("Information for FDA:")
print("   Patient Information:")
print("       Patient Accession Number: ACSN-12345")
print("       Patient Birthday: 06/11/1959")
print("       Patient Birth Sex: Female")
print("       Current Conditions codes: ", code_value_alz, "(Alzheimer's)")
print("                                 ", code_value_hem, "(Microhemorrhage)")
print()
print("       Current Medications codes: 4345-5 (Naproxen)")
print("                                 ", code_value_med, "(Lecanemab)")
print("       Medication Side Effect codes:", code_value_medEffect, "(Microhemorrhage)")
print()
print()
print("Information for clinician:")
print("   Patient may be experincing side effects of current drug")

#This script obtains patient information including current conditions, medications,
#and experienced side effects
# Out:
# Information for FDA:
#    Patient Information:
#        Patient Accession Number: ACSN-12345
#        Patient Birthday: 06/11/1959
#        Patient Birth Sex: Female
#        Current Conditions codes:  G30.9 (Alzheimer's)
#                                   I61.8 (Microhemorrhage)
#
#        Current Medications codes: 4345-5 (Naproxen)
#                                   126202002 (Lecanemab)
#        Medication Side Effect codes: I61.8 (Microhemorrhage)
#
#
# Information for clinician:
#    Patient may be experincing side effects of current drug

# %%
## JSON Bundle

{
  "resourceType" : "Bundle",
  "type" : "collection",
  "total" : "7",
  "entry" : [{

{
  "resourceType": "Patient",
  "id": "siimirene",
  "meta": {
    "versionId": "1",
    "lastUpdated": "2024-06-27T07:04:52.102+00:00",
    "source": "#Nvs8hlFxX5JkzXb6"
  }
  "active": True,
  "gender": "female",
  "birthDate": "1960-06-11",
  "deceasedBoolean": False
}

},
{

{
    "resourceType": "Medication",
    "id": "m126202002",
    "meta": {
        "versionId": "1",
        "lastUpdated": "2024-06-27T07:04:49.767+00:00",
        "source": "#d8XrESTk5pP0zZZE"
    },
    "code": {
        "coding": [
            {
                "system": "http://snomed.info/sct",
                "code": "126202002",
                "display": "Lecanemab"
            }
        ]
    }
}

},
{

{
  "resourceType" : "Condition",
  "clinicalStatus" : "active",
  "code" :  [
    {
      "coding" : {
        "system" : "http://hl7.org/fhir/ValueSet/icd-10",
        "code" : "I61.8"
      },
      "text" : "Other nontraumatic intracerebral hemorrhage"
    }
  ],
  "subject" : {
      "reference" : "Patient/siimirene"
  },
  "evidence" : [
    {
      "detail" : [
        {
          "reference" : "Observation/ob1ID"
        }
      ]
    }
  ]
}

},
{

{
  "resourceType" : "Condition",
  "clinicalStatus" : "active",
  "code" :  [
    {
      "coding" : {
        "system" : "http://hl7.org/fhir/ValueSet/icd-10",
        "code" : "G96.8"
      },
      "text" : "Other specified disorders of central nervous system"
    }
  ],
  "subject" : {
      "reference" : "Patient/siimirene"
  },
  "evidence" : [
    {
      "detail" : [
        {
          "reference" : "Observation/ob2ID"
        }
      ]
    }
  ]
}

},
{

{
  "resourceType" : "Condition",
  "clinicalStatus" : "active",
  "code" :  [
    {
      "coding" : {
        "system" : "http://hl7.org/fhir/ValueSet/icd-10",
        "code" : "F32.A"
      },
      "text" : "Depression, unspecified"
    }
  ],
  "subject" : {
      "reference" : "Patient/siimirene"
  },
  "evidence" : [
    {
      "detail" : [
        {
          "reference" : "Observation/ob3ID"
        }
      ]
    }
  ]
}

},
{

{
  "resourceType" : "Condition",
  "clinicalStatus" : "active",
  "code" :  [
    {
      "coding" : {
        "system" : "http://hl7.org/fhir/ValueSet/icd-10",
        "code" : "G60.3"
      },
      "text" : "Idiopathic progressive neuropathy"
    }
  ],
  "subject" : {
      "reference" : "Patient/siimirene"
  },
  "evidence" : [
    {
      "detail" : [
        {
          "reference" : "Observation/ob4ID"
        }
      ]
    }
  ]
}

},
{

{
  "resourceType" : "Condition",
  "clinicalStatus" : "active",
  "code" :  [
    {
      "coding" : {
        "system" : "http://hl7.org/fhir/ValueSet/icd-10",
        "code" : "G30.9"
      },
      "text" : "Alzheimer's disease, unspecified"
    }
  ],
  "subject" : {
      "reference" : "Patient/siimirene"
  }
}

}]

}

# %%
## CDS Hooks script
{
  "hookInstance": "5a2c302f-5469-4b7a-8e30-5eae5d12d562",
  "hook": "medication-prescribe",
  "fhirServer": "https://example.com/fhir",
  "context": {
    "patientId": "siimirene",
    "encounterId": "67890",
    "medications": [
      {
        "resourceType": "Patient-View",
        "id": "medreq1",
        "status": "draft",
        "intent": "order",
        "medicationCodeableConcept": {
          "coding": [
            {
              "system": "http://snomed.info/sct",
              "code": "126202002",
              "display": "Lecanemab"
            }
          ]
        },
        "subject": {
          "reference": "Patient/siimirene"
        },
        "context": {
          "reference": "Encounter/67890"
        },
        "authoredOn": "2024-06-29T12:00:00Z",
        "requester": {
          "reference": "Practitioner/siimmd"
        }
      }
    ]
  },
  "fhirAuthorization": {
    "access_token": "eyJhbGciOiJSUzI1NiIsImtpZCI6IjYwY2Q3ZjJhLWJlNzMtNDZlNS05ZTdkLTUyM2MzOTViMzAxNCJ9.eyJzdWIiOiJzeXN0ZW06dXNlciIsImF1ZCI6InN5c3RlbTp2cCIsImlzcyI6Imh0dHBzOi8vZXhhbXBsZS5jb20vYXV0aCIsImV4cCI6MTY0NjgxODQwMCwiaWF0IjoxNjQ2ODI1NjAwLCJqdGkiOiI3Njc4YmI4YS1iYmQxLTQ3NDEtYmQ5Zi0wYTRmY2NkZTc2NzYifQ.LHHPDNXyPoaQY5P8ow1qpeTxFb1Ahj7Y_JsXy4r7QKo",
    "token_type": "Bearer",
    "expires_in": 300,
    "scope": "patient/*.read",
    "subject": "Practitioner/siimmd"
  },
  "user": "Practitioner/siimid"
}
